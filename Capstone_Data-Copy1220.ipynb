# %% [markdown]
# # Data Prep  and Acquisition state

# %% [markdown]
# As we discussed earlier that Populations are never static, they grow or decline beacuse of various reasons- births, deaths or migration.
#
# In this stage, we will study change in population for last decade for states within the United States. In this data National Ranking has been listed by the US Census Buearu. I have downloaded the data from https://www.census.gov/data/tables/time-series/demo/popest/2010s-state-total.html, and read it through read_csv() in pandas.
#
#
# A snapshot is as below:
#
# ![image-2.png](attachment:image-2.png)
#
# Based on this data we will find the top 3 states ranked for change in poulation for last decade and will determine which states are growing.
#
# *With some analysis done, I will compare the states on the basis of the " Cost Of Living " parameter and would describe why one outweighs the other. Once we finalize the state , we will follow the Top- down approach to meet the objective of this report.
#
# *In the next step, we will do the analysis for the Top five cities in that state based upon the real estate list price. the data consists of cities and its real estate's  average list price. I have used the refernce of the website :  https://www.businessinsider.com/texas-cities-everyone-is-moving-to-2019-11  for this study.
#
# *We will analyze the city based on Avg Real estate List Price by plotting the graph and based upon that we will select the  city based on the  lower side of the scale of Average Real estate Price.
#
# ![image-3.png](attachment:image-3.png)
#
#
# *Study the city based on other demographic details- We will do the analysis on the city by understanding its demeographics, population growth , and the features like age distribution on the basis of postal codes.The data for this study is described as below:
#
# ![image-4.png](attachment:image-4.png)
#
#
# ![image-7.png](attachment:image-7.png)
#
#
#
# *Plot the city and segment the neighborhoods- In this section we will plot the city using marker labels on the zip . This will help you with the understanding of the geography of the city.
#
# ![image-5.png](attachment:image-5.png)
#
#
#
# ![image-8.png](attachment:image-8.png)
#
#
# *In the last section , using foursquare ApI , we will segment the neighborhood and anayze it draw the conclusion on how to select the neighborhood based upon your needs and your strategies to make an investment or expand a business ,or if its a fresh startups.
#
#
#
# ![image-6.png](attachment:image-6.png)
